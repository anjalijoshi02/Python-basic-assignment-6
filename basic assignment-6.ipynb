# %% [markdown]
# # Python Basic Assignment-6

# %% [markdown]
# #### question 1 : What are escape characters, and how do you use them?

# %% [markdown]
# Escape characters represent characters in string values that would otherwise be difficult or impossible to type into code. we can use the backslash character to escape a single character or symbol.
# eg. \n (for new line)
#     \t (for tabs)

# %% [markdown]
# #### Question 2 : What do the escape characters n and t stand for?

# %% [markdown]
# \n stands for newline
# \t stands for tab

# %% [markdown]
# #### Question 3 : What is the way to include backslash characters in a string?

# %% [markdown]
# The \ \ escape character will include backslash character in the string

# %% [markdown]
# #### Question 4 : The string "Howl's Moving Castle" is a correct value. Why isn't the single quote character in the word Howl's not escaped a problem?

# %% [markdown]
# The string "Howl's Moving castle" escaped the problem because it written within double quotes.    if it was written within single quote, 'Howl's Moving Castle' then we have to use escape character \' to show single quote in the final output.

# %% [markdown]
# #### Question 5 : How do you write a string of newlines if you don't want to use the n character?

# %% [markdown]
# We can insert the string within triple quotes and write the string in newlines .

# %%
a="""This is 
A new Line"""
print(a)
# Out:
# This is
# A new Line

# %% [markdown]
# #### question 6: What are the values of the given expressions?

# %% [markdown]
# 1. 'Hello, world!'[1]    ,          e
# 2. 'Hello, world!'[0:5]  ,         Hello
# 3. 'Hello, world!'[:5]   ,        Hello
# 4. 'Hello, world!'[3:]   ,        lo, world!

# %% [markdown]
# #### Question 7 : What are the values of the following expressions?

# %% [markdown]
# 1. 'Hello'.upper()
# 'HELLO' (upper converts all charactre sinto upper case character)
# 2. 'hello'.upper()isupper()
# True
# This first converts hello in upper case characters and then checks if it is upper or not
# 3. 'Hello'.upper().lower()
# 'hello'
# first converts Hello into upper case charactrea and then into lowe case charactres

# %% [markdown]
# #### question 8 : What are the values of the following expressions?
# #### 'Remember, remember, the fifth of July.'.split()

# %% [markdown]
# 'x y z'.split() returns the list of individual word.
# so value of this expresiion would be
# ['remember', 'remember', 'the','fifth','of','July.']

# %% [markdown]
# #### Question 9 : What are the methods for right-justifying, left-justifying, and centering a string?

# %% [markdown]
# use rjust() for right justifying
# ljust() for left justifying and center() for centering a string

# %% [markdown]
# #### Question 10: What is the best way to remove whitespace characters from the start or end?

# %% [markdown]
# lstrip() and rstrip() removes the whitespace characters from left and right end of the string respectively
